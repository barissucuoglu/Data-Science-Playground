# %%
import pandas as pd

# %%
df = pd.read_csv("data/AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_treshold, max_treshold = df.price.quantile(0.01), df.price.quantile(0.999)
max_treshold
# Out:
# 3000.0

# %%
min_treshold, max_treshold = df.price.quantile([0.01,0.999])
min_treshold, max_treshold
# Out:
# (30.0, 3000.0)

# %%
df[df.price < max_treshold]
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df2 = df[(df.price > min_treshold) & (df.price < max_treshold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(5)
# Out:
#              id                                              name   host_id  \
# 29623  22747209        McSimon's | Cozy Private Studio | Near NYC   8113165
# 21154  16791809  Small Brooklyn Gem 25 Minutes Away from the City   1938828
# 28806  22244184   Luxury Private Bed, Bath & Desk in Williamsburg  45858744
# 15305  12253809                 Beautiful View of Hudson and City  12608878
# 12550   9646874                      Cozy, bohemian, modern oasis   1120455
#
#                  host_name neighbourhood_group       neighbourhood  latitude  \
# 29623  Cynthia And Froebel            Brooklyn            Canarsie  40.63762
# 21154                 Shay            Brooklyn       East Flatbush  40.65071
# 28806            Augustine            Brooklyn        Williamsburg  40.70755
# 15305                 Doug           Manhattan  Washington Heights  40.85280
# 12550               Shetal            Brooklyn          Greenpoint  40.72798
#
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64
