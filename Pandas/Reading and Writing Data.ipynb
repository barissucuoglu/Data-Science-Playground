# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col="Respondent")
scheme_df = pd.read_csv("data/survey_results_schema.csv", index_col="Column")

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = df["Country"] == "Germany"
germany_df = df.loc[filt]
germany_df.head()
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 14          I am a developer by profession      Yes
# 36          I am a developer by profession      Yes
# 44          I am a developer by profession      Yes
# 66          I am a developer by profession      Yes
# 85          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 14                                    Less than once per year
# 36          Less than once a month but more than once per ...
# 44                                 Once a month or more often
# 66                                 Once a month or more often
# 85                                                      Never
#
#                                                    OpenSource  \
# Respondent
# 14          The quality of OSS and closed source software ...
# 36          The quality of OSS and closed source software ...
# ...

# %%
germany_df.to_csv("data/modified.csv")

# %%
germany_df.to_csv("data/modified.csv", sep="\t")

# %%
germany_df.to_excel("data/modified.xlsx")

# %%
test = pd.read_excel("data/modified.xlsx", index_col="Respondent")

# %%
test.head(5)
# Out:
#                        MainBranch Hobbyist  \
# 0  I am a developer by profession      Yes
# 1  I am a developer by profession      Yes
# 2  I am a developer by profession      Yes
# 3  I am a developer by profession      Yes
# 4  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                            Less than once per year
# 1  Less than once a month but more than once per ...
# 2                         Once a month or more often
# 3                         Once a month or more often
# 4                                              Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  OSS is, on average, of HIGHER quality than pro...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
germany_df.to_json("data/modified.json", orient="records", lines=True)

# %%
test = pd.read_json("data/modified.json", orient="records", lines=True)

# %%
test.head(3)
# Out:
#                        MainBranch Hobbyist  \
# 0  I am a developer by profession      Yes
# 1  I am a developer by profession      Yes
# 2  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                            Less than once per year
# 1  Less than once a month but more than once per ...
# 2                         Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  The quality of OSS and closed source software ...  Employed full-time
#
#    Country         Student                                            EdLevel  \
# 0  Germany              No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 1  Germany  Yes, full-time  Secondary school (e.g. American high school, G...
# ...

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine("postgresql://dbuser:dbpass@localhost:54321/sample_db")

# %%
germany_df.to_sql("sample_table", engine, if_exists="replace")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...
